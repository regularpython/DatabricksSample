# %%
sales_data = """order_id,product,quantity,price
1,Mobile,2,10000
2,Laptop,1,50000
3,Mouse,-1,500
"""

dbutils.fs.put(
    "/Volumes/dsr_catalog/medallion/bronze_vol/raw_sales.csv",
    sales_data,
    overwrite=True
)
